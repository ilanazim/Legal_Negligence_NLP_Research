# %% [markdown]
# #### Libraries

# %%
import re
from collections import defaultdict
import nltk
import pandas as pd

# %% [markdown]
# #### Global Variables to aid with filenames

# %%
path_to_data = '../data/Lexis Cases txt/'
file_prefix = 'P'
file_suffix = '.txt'
file_identifiers = range(1, 86) # Range from 1 to 85

# %% [markdown]
# #### Code to parse each single document
#
# # WORK IN PROGRESS
# ##### Currently is able to print out the Decision Length, Judge Name, Year, and Registry Loc of any record

# %%
def parse_chfl_case(doc):
    lines = doc.split('\n')
    doc_dict = dict() # fill in later :) 
    registry = None
    decision_len = 0
    judge_name = lines[3][8:]
    case_title = lines[0]
    year = re.search(r'20[0-2][0-9]', case_title) # Limit regex to be from 2000 to 2029
    
    print('CASE TITLE:', case_title)
    print('REGISTRY:', registry)
    
    if year:
        print('YEAR:', year.group(0))
    print('JUDGE NAME:', judge_name)
    print('DECISION LENGTH:', decision_len) # Pull out dec. length number
    
    print('====================')
    
def parse_ilr_case(doc):
    lines = doc.split('\n')
    doc_dict = dict() # fill in later :) 
    registry = None
    judge_name = lines[3][8:]
    case_title = lines[0]
    year = re.search(r'20[0-2][0-9]', case_title) # Limit regex to be from 2000 to 2029
    
    # Search for decision length (Verified this works on 6 different cases)
    # Logic: Start at 1. If we find a line following the current that is +1 of the decision length
    #        then we increment it. This should help avoid if a line begins with a different number
    #        because the decisions should be properly incrementing by 1 each time.
    decision_len = 0
    for line in lines:
        if line.startswith('Reasons for Judg') or line.lower().startswith('introduction'):
            decision_len = 1
            
        if line.startswith(str(decision_len + 1)):
            decision_len += 1
    
    print('CASE TITLE:', case_title)
    print('REGISTRY:', registry)
    
    if year:
        print('YEAR:', year.group(0))
    print('JUDGE NAME:', judge_name)
    print('DECISION LENGTH:', decision_len) # Pull out dec. length number
    
    print('====================')

def parse_cnlr_case(doc):
    lines = doc.split('\n')
    doc_dict = dict() # fill in later :) 
    registry = None
    judge_name = lines[3]
    case_title = lines[0]
    year = re.search(r'20[0-2][0-9]', case_title) # Limit regex to be from 2000 to 2029
    
    # Search for decision length (Verified this works on 6 different cases)
    # Logic: Start at 1. If we find a line following the current that is +1 of the decision length
    #        then we increment it. This should help avoid if a line begins with a different number
    #        because the decisions should be properly incrementing by 1 each time.
    decision_len = 0
    for line in lines:
        if line.startswith('Reasons for Judg') or line.lower().startswith('introduction'):
            decision_len = 1
            
        if line.startswith(str(decision_len + 1)):
            decision_len += 1
    
    print('CASE TITLE:', case_title)
    print('REGISTRY:', registry)
    
    if year:
        print('YEAR:', year.group(0))
    print('JUDGE NAME:', judge_name)
    print('DECISION LENGTH:', decision_len) # Pull out dec. length number
    
    print('====================')
    
def parse_dtc_case(doc):
    lines = doc.split('\n')
    doc_dict = dict() # fill in later :) 
    registry = None
    judge_name = lines[5][9:]
    case_title = lines[0]
    year = re.search(r'20[0-2][0-9]', case_title) # Limit regex to be from 2000 to 2029
    
    # Search for decision length (Verified this works on 6 different cases)
    # Logic: Start at 1. If we find a line following the current that is +1 of the decision length
    #        then we increment it. This should help avoid if a line begins with a different number
    #        because the decisions should be properly incrementing by 1 each time.
    decision_len = 0
    for line in lines:
        if line.startswith('Reasons for Judg') or line.lower().startswith('introduction'):
            decision_len = 1
            
        if line.startswith(str(decision_len + 1)):
            decision_len += 1
    
    print('CASE TITLE:', case_title)
    print('REGISTRY:', registry)
    
    if year:
        print('YEAR:', year.group(0))
    print('JUDGE NAME:', judge_name)
    print('DECISION LENGTH:', decision_len) # Pull out dec. length number
    
    print('====================')
    
def parse_bcj_case(doc):
    '''given a string of the entire document, extract relevant info - return dictionary of values'''
    lines = doc.split('\n')
    
    doc_dict = dict() # fill in later :) 
    
    # Simple Regex Fields
    case_no = re.search(r'\[[0-9]{4}\] [[A-Z|\.]+ No\. [0-9]+', doc)
    registry = re.search(r'Registry: ?([A-Za-z ]+)', doc)
    decision_len = re.search(r'\(([0-9]+) paras\.?\)', doc)
    
    # Fields that are always in the same place
    judge_name = lines[4].strip()
    case_title = lines[0].strip()
    # Extract year from case_title (in case we want to make visualizations, etc.)
    year = re.search(r'20[0-2][0-9]', case_title) # Limit regex to be from 2000 to 2029
    
    print('CASE TITLE:', case_title)
    if registry:
        print('REGISTRY:', registry.group(1).strip()) # Get rid of newline
    else:
        registry = re.search(r'([A-Za-z ]+) Registry No.', doc)
        if registry:
            print('(alt method) REGISTRY:', registry.group(1))
        else:
            print('@@@@ ERROR: UNABLE TO FIND REGISTRY @@@@')
    
    if year:
        print('YEAR:', year.group(0))
    print('JUDGE NAME:', judge_name)
    print('DECISION LENGTH:', decision_len.group(1)) # Pull out dec. length number
    
    print('====================')
    
def rule_based_parse_BCJ(doc):
    '''Given an entire case, finds static information within the case (information that can be pattern matched)
    Expects a B.C.J. case format (British Columbia Judgments)
    
    The following fields are currently implemented:
    - Case Title
    - Judge Name
    - Registry
    - Year
    - Decision Length (in paragraphs)
    
    The following fields are still being implemented & tweaked:
    - Multiple Defendants
    
    Arguments: doc (String): The case in text format following the form used in the DOCX to TXT notebook
    Returns: case_dict (Dictionary): Dictionary with rule based parsable fields filled in
    '''
    lines = doc.split('\n')
    case_dict = dict() 
    
    # Fields that can be found via pattern matching
    decision_len = re.search(r'\(([0-9]+) paras\.?\)', doc) # e.g.) (100 paras.)
    registry = re.search(r'(Registry|Registries): ?([A-Za-z0-9 ]+)', doc) # e.g.) Registry: Vancouver
    if registry:
        registry = registry.group(2).strip()
    else:
        registry = re.search(r'([A-Za-z ]+) Registry No.', doc) # Alt form e.g.) Vancouver Registory No. XXX
        if registry:
            registry = registry.group(1).strip()
        else:
            registry = re.search(r'([A-Za-z ]+) No. S[0-9]*', doc)
            if registry:
                registry = registry.group(1).strip()
            else:
                print('WARNING: Registry could not be found (This shouldn\'t occur!)')

    
    # Fields that are always in the same place
    judge_name = lines[4].strip()
    case_title = lines[0].strip()
    
    # Extract year from case_title (in case we want to make visualizations, etc.)
    year = re.search(r'20[0-2][0-9]', case_title) # Limit regex to be from 2000 to 2029
    if year:
        year = year.group(0)
    else:
        # Rare case: Sometimes the title is too long. Rely on Heard date.
        year = re.search(r'Heard:.* ([2][0][0-2][0-9])', doc)
        if year:
            year = year.group(1)
        else:
            print('WARNING: Year not found')
    
    case_dict['case_title'] = case_title
    case_dict['year'] = year
    case_dict['registry'] = registry
    case_dict['judge'] = judge_name
    case_dict['decision_length'] = decision_len.group(1)
    case_dict['multiple_defendants'] = rule_based_multiple_defendants_parse(doc)
    case_dict['damages'] = rule_based_damage_extraction(doc)
    
    return case_dict
    
def rule_based_multiple_defendants_parse(doc):
    ''' 
    
    Given a case. Uses regex/pattern-matching to determine whether we have multiple defendants.
    For the most part the logic relies on whether the langauge used implies plurality or not.
    
    Arguments: doc (String): The case in text format following the form used in the DOCX to TXT notebook
    Returns: response (String, 'Y', 'N', or 'UNK' if unable to parse)
    
    '''
    
    
    # Case 1)
    # Traditional/most common. Of form "Between A, B, C, Plaintiff(s), X, Y, Z Defendant(s)"
    # Will also allow "IN THE MATTER OF ... Plaintiff .... Defendant..."
    # Can successfully cover ~98% of data
    regex_between_plaintiff_claimant = re.search(r'([Between|IN THE MATTER OF].*([P|p]laintiff[s]?|[C|c]laimant[s]?|[A|a]ppellant[s]?|[P|p]etitioner[s]?|[R|r]espondent[s]?).*([D|d]efendant[s]?|[R|r]espondent[s]?|[A|a]pplicant[s]?).*\n)', doc)
    
    # Match found
    if regex_between_plaintiff_claimant:
        text = regex_between_plaintiff_claimant.group(0).lower()
        if 'defendants' in text or 'respondents' in text or 'applicants' in text: # Defendant/respondent same thing.
            return 'Y'
        elif 'defendant' in text or 'respondent' in text or 'applicant' in text:
            return 'N'
    
    # If not found, try other less common cases
    else:
        # Case 2)
        # Sometimes it does not mention the name of the second item. (Defendent/Respondent)
        # We can estimate if there are multiple based on the number of "," in the line (Covers all cases in initial data)
        regex_missing_defendent = re.search(r'(Between.*([P|p]laintiff[s]?|[C|c]laimant[s]?|[A|a]ppellant[s]?|[P|p]etitioner[s]?).*\n)', doc)
        if regex_missing_defendent:
            text = regex_missing_defendent.group(0).lower()
            if len(text.split(',')) > 5:
                return 'Y'
            else:
                return 'N'
            
        else:
            print('Multiple defendants: Unknown! Unable to regex match')
            return 'UNK'
    
def rule_based_damage_extraction(doc, min_score = 0.85, max_match_len_split = 10):
    '''Given a case, attempts to extract damages using regex patterns
    
    Arguments: doc (String): The case in text format following the form used in the DOCX to TXT notebook
    min_score (float): The minimum paragraph score to consider having a valid $ number
                       Paragraph has score 1 if its the last paragraph
                       Paragraph has score 0 if its the first paragraph
    max_match_len_split (int): The max amount of items that can appear in a regex match after splitting (no. words)
    
    Returns: damages (Dict): Contains any found damages
    
    '''
    damages = defaultdict(float)
    repetition_detection = defaultdict(set) # try to stem the repeated values
    no_paras = re.search(r'\(([0-9|,]+) paras?\.?\)', doc).group(1) # Get number of paragraphs
    pattern = r'[\W|\w]?(?=\n[0-9]{1,%s}[\xa0|\s| ]{2})'%len(no_paras) # Used to split into paras
    paras_split = re.split(pattern, doc)
    money_patt = r'\$[0-9|,]+' # Used to get all paragraphs with a money amount
    scored_paras = [] # Score paragraphs based on where they appear in the document
                      # Score of 0.0 would be the first paragraph. Score of 1.0 would be the last paragraph
        
    for i, paragraph in enumerate(paras_split):
        if re.search(money_patt, paragraph):
            scored_paras.append((i / len(paras_split), paragraph)) # (score, paragraph). Score formula: i/no_paras
            
    scored_paras = sorted(scored_paras, key=lambda x:x[0])[::-1] # Store from last paragraph to first
    if len(scored_paras) == 0: # If no $ amount is mentioned
        return None
    if scored_paras[0][0] < min_score: # If last $ amount isn't mentioned late enough in the text
        return None
    
    # Form: X damages: $5 -- i.e. Non-pecuniary damages $5000
    regex_damages = r'[\w|-]* ?(?:damage|loss|capacity).+?\$? ?[0-9][0-9|,|.]+[0-9]'
    regex_alt_damages = r'\$? ?[0-9][0-9|,|.]+[0-9] (?:for|representing)?[ \w\-+]+damages?'
    regex_future_care_loss = r'(?:future|past|in-?trust|award).*?(?:loss|costs?|income|care)?.*?\$? ?[0-9][0-9|,|.]+[0-9]'
    regex_for_cost_of = r'\$? ?[0-9][0-9|,|.]+[0-9]?[\w ]*? cost .*?\.'
    
    #regex_in_trust = r'(?:in-?trust|award).*?\$? ?[0-9][0-9|,|.]+[0-9]'
    patterns = [regex_damages, regex_alt_damages, regex_future_care_loss, regex_for_cost_of]
    
    # Words that tend to mean someoen is asking for this amount of money
    # Or they are describing a previous case
    banned_words = ['seek', 'claim', 'propose', 'range', ' v. ']
    # If these words appear. Ignore the banned_words.
    counter_words = ['summary']
    
    # Get money mounts from the text
    total = None
    matches = []
    for score, text in scored_paras:
        if score > min_score:
            skip = False
            for banned_word in banned_words: # Skip paras with banned words
                if banned_word in text:
                    skip = True       
            for counter_word in counter_words:
                if counter_word in text:
                    skip = False
            if skip:
                continue
            
            text_matches = get_matching_text(patterns, text, max_match_len_split)
            for t_m in text_matches:
                matches.append((score, t_m))

                    
    print('Matches:')
    print(matches)
    # Convert money amounts into actual float values
    # Determine which column they should fit into.
    regex_number_extraction = r'[0-9][0-9|,|.]+'
    for score, match in matches:
        skip = False
        for banned_word in banned_words: # If it had "Summary" banned words may appear here.
            if banned_word in match:     # Its ok to be in the paragraph but not the match itself.
                skip=True
                break
        if skip:
            continue
        
        amount = re.search(regex_number_extraction, match, re.IGNORECASE)
        extracted_value = None
        if amount:
            amount = amount.group(0).replace(',', '')
            if amount[-1] == '.':
                amount = amount[:-1]
            extracted_value = float(amount)
        else:    
            print('Error: Has no money amount?', match)
            
        value_extracted = False
        
        if not value_extracted:
            general_damage_keywords = [('general',), ('future', 'income', 'loss'), ('future', 'income'), ('future', 'wage', 'loss'), ('future', 'earning'), ('earning', 'capacity')]
            for keywords in general_damage_keywords:
                if all(word in match.lower() for word in keywords):
                    value_extracted = True
                    if best_score_item(score, matches, keywords):
                        if extracted_value not in repetition_detection['General']:
                            
                            damages['General'] += extracted_value
                            repetition_detection['General'].add(extracted_value)
                    break
        
        if not value_extracted:
            special_damage_keywords = [('special',), ('trust',), ('past', 'income', 'loss'), ('past', 'wage'), ('past', 'earning'), ('past', 'income')]
            for keywords in special_damage_keywords:
                if all(word in match.lower() for word in keywords):        
                    value_extracted = True
                    if best_score_item(score, matches, ('special',)):
                        if extracted_value not in repetition_detection[('special',)]:
                            damages['Special'] += extracted_value
                            repetition_detection[('special',)].add(extracted_value)
                        
        if not value_extracted:
            if 'aggravated' in match.lower():
                value_extracted = True
                if best_score_item(score, matches, ('aggravated',)):
                    if extracted_value not in repetition_detection[('aggravated',)]:
                        damages['Aggravated'] += extracted_value
                        repetition_detection[('aggravated',)].add(extracted_value)
                            
        if not value_extracted:
            if 'non' in match.lower() and 'pecuniary' in match.lower():
                value_extracted = True
                if best_score_item(score, matches, ('non', 'pecuniary')):
                    if extracted_value not in repetition_detection[('non', 'pecuniary')]:
                        damages['Non-pecuniary'] += extracted_value
                        repetition_detection[('non', 'pecuniary')].add(extracted_value)
                            
        if not value_extracted:
            if 'punitive' in match.lower():
                value_extracted = True
                if best_score_item(score, matches, ('punitive',)):
                    if extracted_value not in repetition_detection[('punitive',)]:
                        damages['Punitive'] += extracted_value
                        repetition_detection[('punitive',)].add(extracted_value)                    
                        
                        
        if not value_extracted:
            future_care_keywords = [('future', 'care'), ('future', 'cost')]
            for keywords in future_care_keywords:
                if all(word in match.lower() for word in keywords):
                    value_extracted = True
                    if best_score_item(score, matches, keywords):
                        if extracted_value not in repetition_detection[keywords]:
                            damages['Future Care'] += extracted_value
                            repetition_detection[keywords].add(extracted_value)
                    break
                            
        if not value_extracted:
            total_keywords = [('total',), ('sum',), ('award',)]
            for keywords in total_keywords:
                if all(word in match.lower() for word in keywords):
                    value_extracted=True
                    if best_score_item(score, matches, keywords):
                        # Only set the "total" if does not match any if statement above and
                        # it is not the same as adding up all of the values manually.
                        if extracted_value not in repetition_detection[('total',)]:
                            damages['Pecuniary Total'] = damages['Special'] + damages['General'] + damages['Punitive'] + damages['Aggravated'] + damages['Future Care']
                            damages['Total'] = damages['Pecuniary Total'] + damages['Non-pecuniary']
                            if damages['Total'] == 0:
                                total = extracted_value
                                repetition_detection[('total',)].add(extracted_value)
                        
    damages['Pecuniary Total'] = damages['Special'] + damages['General'] + damages['Punitive'] + damages['Aggravated'] + damages['Future Care']
    damages['Total'] = damages['Pecuniary Total'] + damages['Non-pecuniary']
    
    if damages['Total'] == 0: # only use the "total" if we couldnt find anything else. Otherwise add it up
    
        damages['Total'] = total
        damages['General'] = total
    
    
    if damages['Total'] == 0 or damages['Total'] is None:
        damages['Pecuniary Total'] = None
        damages['Special'] = None
        damages['General'] = None
        damages['Punitive'] = None
        damages['Aggravated'] = None
        damages['Future Care'] = None
        damages['Non-pecuniary'] = None
        damages['Total'] = None

    print(damages)
    return damages


def get_matching_text(patterns, text, max_match_len_split):
    '''
    Given a set of regex; pulls out all matching text
    
    Arguments:
    patterns (list) - List of regex patterns in string format
    text (string) - Text to search for matches in
    
    Returns:
    matches (list) - List containing all matches in text format
    '''

    matches = []
    for pattern in patterns:
        for match in re.findall(pattern, text, re.IGNORECASE):
            if 'and' not in match:
                if len(match.split()) <= max_match_len_split:
                    matches.append(match)
                    
    return matches
    
def is_best_score(score, matches, keywords):
    '''
    Given a set of regex matches, determine if the score is the highest score out of all matches for the given keywords
    
    Arguments:
    score (float) - The score of the item you're inspecting
    matches (list) - List of matches where each element is of form (score, match text)
    keywords (tuple) - All words that should appear in the match
    
    Returns: True or False
    
    '''
    best_score = score
    
    for score, match in matches:
        if all(word in match.lower() for word in keywords):
            if score > best_score:
                return False
            
    return True
    
def rule_based_convert_to_DF(cases):
    '''temp function. i think ilana has a better one'''
    
    cols = cases[0].keys()
    
    titles = []
    years = []
    judges = []
    dec_len = []
    mul_def = []
    
    total_dmg = []
    total_pec_total = []
    non_pec = []
    punitive = []
    aggravated = []
    special = []
    general = []
    future_care = []
    
    for case in cases:
        titles.append(case['case_title'])
        years.append(case['year'])
        judges.append(case['judge'])
        dec_len.append(case['decision_length'])
        mul_def.append(case['multiple_defendants'])
        
        if case['damages'] is not None:
            total_dmg.append(case['damages']['Total'])
            total_pec_total.append(case['damages']['Pecuniary Total'])
            non_pec.append(case['damages']['Non-pecuniary'])
            punitive.append(case['damages']['Punitive'])
            aggravated.append(case['damages']['Aggravated'])
            special.append(case['damages']['Special'])
            general.append(case['damages']['General'])
            future_care.append(case['damages']['Future Care'])
        else:
            total_dmg.append(None)
            total_pec_total.append(None)
            non_pec.append(None)
            punitive.append(None)
            aggravated.append(None)
            special.append(None)
            general.append(None)
            future_care.append(None)
        
        
    df = pd.DataFrame()
    df['Title'] = titles
    df['Year'] = years
    df['Total Damage'] = total_dmg
    df['Total Pecuniary'] = total_pec_total
    df['Non pecuniary'] = non_pec
    df['General'] = general
    df['Special'] = special
    df['Aggravated'] = aggravated
    df['Future Care'] = future_care
    df['Punitive'] = punitive
    df['Judge'] = judges
    df['Decision Length'] = dec_len
    df['Multiple Defendants'] = mul_def
    
    return df

# %% [markdown]
# #### Code driver

# %%
case_type_counts = defaultdict(int)
cases = 0
data = []
for file_number in file_identifiers:

    print('## Processing ' + path_to_data + file_prefix + str(file_number) + file_suffix + ' ##\n')
    document_data = None
    
    with open(path_to_data + file_prefix + str(file_number) + file_suffix, 'r') as document:
        document_data = document.read()
        
    document_data = document_data.split('End of Document\n') # Always split on 'End of Document\n'
    
    case_parsed_data = []
    for case in document_data:
        case = case.strip() # Make sure to strip!

        if len(case) == 0: # Skip empty lines
            continue

        case_title = case.split('\n')[0]
        case_type = case.split('\n')[1]

        # Skip crown cases
        # Skip Re: cases
        if 'R. v.' in case_title or '(Re)' in case_title: 
            continue
            
        # Skip client/solicitor cases (not same as plaintiff/defendant)
        regex_client_solicitor = re.search(r'(Between.*([C|c]lient[s]?).*([S|s]olicitor[s]?|[L|l]awyer[s]?))', case)
        if regex_client_solicitor:
            continue
        
        regex_solicitor_client = re.search(r'(Between.*([L|l]awyer[s]?|[S|s]olicitor[s]?).*([C|c]lient[s]?))', case)
        if regex_solicitor_client:
            continue
            
        key_words = ['appellant', 'respondent', 'claimant', 'petitioner', 'plaintiff', 'defendant',
        'appellants', 'respondents', 'claimants', 'petitioners', 'plaintiffs', 'defendants']
        regex_in_matter_of = re.search(r'IN THE MATTER OF .*\n\([0-9]+ paras.\)', case)
        if regex_in_matter_of:
            remove = True
            for key in key_words:
                if key in regex_in_matter_of.group(0).lower().strip():
                    remove = False
                    
            if remove:
                continue

        if 'British Columbia Judgments' in case_type: # Make sure we're dealing with a B.C.J. case
            cases += 1
            #case_parsed_data.append(rule_based_parse_BCJ(case))
            print(case_title)
            data.append(rule_based_parse_BCJ(case))
            
        break
        
        
print('Total cases being used:', cases)
# Out:
# ## Processing ../data/Lexis Cases txt/P1.txt ##
#
# Mawani v. Pitcairn, [2012] B.C.J. No. 1819
# ## Processing ../data/Lexis Cases txt/P2.txt ##
#
# ## Processing ../data/Lexis Cases txt/P3.txt ##
#
# Brooks-Martin v. Martin, [2011] B.C.J. No. 243
# ## Processing ../data/Lexis Cases txt/P4.txt ##
#
# McGavin v. Talbot, [2017] B.C.J. No. 2439
# Matches:
# [(0.9747899159663865, 'General Damages (First Accident): $65,000.00'), (0.9747899159663865, 'General Damages (Second Accident): $7,000.00'), (0.9747899159663865, ' Loss of Past Income Earning Opportunity: $9,000.00'), (0.9747899159663865, 'Special Damages: $6,636.82'), (0.9747899159663865, '$65,000.00 General Damages'), (0.9747899159663865, '$900.00 Special Damages'), (0.9747899159663865, 'Past Income Earning Opportunity: $9,000.00'), (0.9747899159663865, 'Future Care: $900.00'), (0.9747899159663865, '$9,000.00 Cost of Future Care: $900.'), (0.957983193277311, 'special damages is $6,636.82'), (0.8739495798319328, 'award of $1,800'), (0.8571428571428571, 'award of $9,000')]
# defaultdict(<class 'float'>, {'General': 72000.0, 'Special': 16536.82, 'Future Care': 9900.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Pecuniary Total': 98436.82, 'Non-pecuniary': 0.0, 'Total': 98436.82})
# ## Processing ../data/Lexis Cases txt/P5.txt ##
#
# Mclaren v. Rice, [2009] B.C.J. No. 2108
# ## Processing ../data/Lexis Cases txt/P6.txt ##
#
# Jacobs v. Basil, [2017] B.C.J. No. 1517
# Matches:
# [(0.9934640522875817, 'general damages: $115,000'), (0.9934640522875817, 'past loss of earning capacity: $15,000'), (0.9934640522875817, 'future loss of earning capacity: $115,000'), (0.9934640522875817, 'awarded $5,000'), (0.9934640522875817, 'past loss of earning capacity: $15,000'), (0.9934640522875817, 'future loss of earning capacity: $115,000'), (0.9934640522875817, 'future care: $50,000'), (0.9281045751633987, '$50,000 under this head of damage'), (0.9281045751633987, 'awarded $50,000'), (0.8583877995642701, 'award of at most $50,000')]
# defaultdict(<class 'float'>, {'General': 130000.0, 'Special': 0.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 50000.0, 'Pecuniary Total': 180000.0, 'Non-pecuniary': 0.0, 'Total': 180000.0})
# ## Processing ../data/Lexis Cases txt/P7.txt ##
#
# Jackson v. Fisheries and Oceans Canada, [2006] B.C.J. No. 2654
# ## Processing ../data/Lexis Cases txt/P8.txt ##
#
# Brito (Guardian ad litem of) v. Woolley, [2001] B.C.J. No. 1692
# Matches:
# [(0.995053003533569, 'Special Damages $259,239.50'), (0.995053003533569, 'Future Loss of Earning Capacity $864,661.21'), (0.995053003533569, 'Non-Pecuniary Damages $260,000.00'), (0.995053003533569, 'In-Trust Claim $122,134.50'), (0.995053003533569, 'Future Loss of Earning Capacity $864,661.21'), (0.9936395759717315, 'non-pecuniary damages is set $260,000.00'), (0.9936395759717315, 'award for non-pecuniary damages is set $260,000.00'), (0.9893992932862191, 'awarded something less than $260,000.00'), (0.9879858657243816, 'non-pecuniary damages in the amount of $260,000.00'), (0.9752650176678446, 'income loss is $864,661.21'), (0.9752650176678446, 'award for future income loss is $864,661.21'), (0.9512367491166078, 'income loss with a present value of $830,246.34'), (0.8890459363957597, 'award of $1,020.00'), (0.8890459363957597, 'award of $340.00'), (0.8777385159010601, 'award of $3,000.00'), (0.8777385159010601, 'award of $4,500.00')]
# defaultdict(<class 'float'>, {'Special': 381374.0, 'General': 864661.21, 'Non-pecuniary': 260000.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 1246035.21, 'Total': 1506035.21})
# ## Processing ../data/Lexis Cases txt/P9.txt ##
#
# Rackstraw (Litigation guardian of) v. Robertson, [2011] B.C.J. No. 1354
# ## Processing ../data/Lexis Cases txt/P10.txt ##
#
# Intrawest Corp. v. Hart, [2002] B.C.J. No. 301
# Matches:
# [(0.9673202614379085, 'total damages at $353,519.11')]
# defaultdict(<class 'float'>, {'Special': 0.0, 'General': 353519.11, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 0.0, 'Non-pecuniary': 0.0, 'Total': 353519.11})
# ## Processing ../data/Lexis Cases txt/P11.txt ##
#
# Millard v. Singleton, [2015] B.C.J. No. 1234
# ## Processing ../data/Lexis Cases txt/P12.txt ##
#
# C.H. v. British Columbia, [2003] B.C.J. No. 1706
# Matches:
# [(0.9936305732484076, '$127,500 for general damages'), (0.9936305732484076, '$10,000 aggravated damages'), (0.9936305732484076, 'award of $127,500'), (0.9936305732484076, '$15,000 for the cost of future therapy.'), (0.9808917197452229, '$130 per hour will cost approximately $5,000.'), (0.9596602972399151, '$10,000 aggravated damages'), (0.9554140127388535, 'general damages at $135,000'), (0.9384288747346072, '$175,000 is an appropriate range for non-pecuniary damages')]
# defaultdict(<class 'float'>, {'General': 127500.0, 'Aggravated': 10000.0, 'Special': 0.0, 'Punitive': 0.0, 'Future Care': 15000.0, 'Pecuniary Total': 152500.0, 'Non-pecuniary': 0.0, 'Total': 152500.0})
# ## Processing ../data/Lexis Cases txt/P13.txt ##
#
# N&C Transportation Ltd. v. Navistar International Corp., [2016] B.C.J. No. 2369
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P14.txt ##
#
# Aiken (Guardian ad litem of) v. Van Dyk, [2001] B.C.J. No. 1751
# ## Processing ../data/Lexis Cases txt/P15.txt ##
#
# Ahlwat v. Green, [2014] B.C.J. No. 2452
# ## Processing ../data/Lexis Cases txt/P16.txt ##
#
# ## Processing ../data/Lexis Cases txt/P17.txt ##
#
# Logeman v. Rossa, [2006] B.C.J. No. 963
# ## Processing ../data/Lexis Cases txt/P18.txt ##
#
# Ellis (Litigation guardian of) v. Duong, [2017] B.C.J. No. 546
# Matches:
# [(0.9977011494252873, 'Non-pecuniary damages: $ 220,000.00'), (0.9977011494252873, ' Loss of Future Income Capacity: $ 730,000.00'), (0.9977011494252873, 'Special Damages: $ 6,074.19'), (0.9977011494252873, 'Future Income Capacity: $ 730,000.00'), (0.9977011494252873, 'Future Care Costs: $ 222,360.00'), (0.993103448275862, 'special damages incurred to the date of trial is $6,074.19'), (0.9839080459770115, 'award $3,500'), (0.9471264367816092, 'award a present value for these items at $4,700'), (0.9287356321839081, 'award the present value of the cost at $12,000'), (0.9057471264367816, 'award $772'), (0.9011494252873563, 'award an amount of $1,670'), (0.8505747126436781, 'the loss would be $10,000')]
# defaultdict(<class 'float'>, {'Non-pecuniary': 220000.0, 'General': 730000.0, 'Special': 6074.19, 'Future Care': 222360.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Pecuniary Total': 958434.19, 'Total': 1178434.19})
# ## Processing ../data/Lexis Cases txt/P19.txt ##
#
# Los Angeles Salad Co. v. Canadian Food Inspection Agency, [2009] B.C.J. No. 161
# ## Processing ../data/Lexis Cases txt/P20.txt ##
#
# Harder v. Poettcker, [2015] B.C.J. No. 2579
# ## Processing ../data/Lexis Cases txt/P21.txt ##
#
# Fabian v. Song, [2018] B.C.J. No. 896
# Matches:
# [(0.9891696750902527, 'following damages, totaling $113,599.25'), (0.9891696750902527, 'non-pecuniary damages of $70,000'), (0.9891696750902527, 'damages for past loss of earning capacity of $36,000'), (0.9891696750902527, 'damages for future cost of care of $3,000'), (0.9891696750902527, 'special damages of $4,599.25'), (0.9891696750902527, 'past loss of earning capacity of $36,000'), (0.9891696750902527, 'future cost of care of $3,000'), (0.9602888086642599, '$4,599.25 is payable by way of special damages'), (0.9530685920577617, 'award the sum of $2,500'), (0.8736462093862816, 'past loss of earning capacity, should be assessed at $36,000'), (0.8664259927797834, 's losses by assuming that 100'), (0.851985559566787, 'income loss would be approximately $17,500'), (0.851985559566787, 'past income past income loss would be approximately $17,500')]
# defaultdict(<class 'float'>, {'Special': 4599.25, 'General': 36000.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 3000.0, 'Pecuniary Total': 43599.25, 'Non-pecuniary': 70000.0, 'Total': 113599.25})
# ## Processing ../data/Lexis Cases txt/P22.txt ##
#
# Fichtner v. Johnston Meier Insurance Services Ltd., [2001] B.C.J. No. 1666
# ## Processing ../data/Lexis Cases txt/P23.txt ##
#
# Dr. Andrew Hokhold Inc. v. Wells (c.o.b. Spall Machine & Welding), [2005] B.C.J. No. 255
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P24.txt ##
#
# Paniccia v. Eckert, [2012] B.C.J. No. 1997
# Matches:
# [(0.9747292418772563, 'to damages in the sum of $6,037')]
# defaultdict(<class 'float'>, {'Special': 0.0, 'General': 6037.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 0.0, 'Non-pecuniary': 0.0, 'Total': 6037.0})
# ## Processing ../data/Lexis Cases txt/P25.txt ##
#
# Austin v. Joaquin, [2007] B.C.J. No. 1894
# ## Processing ../data/Lexis Cases txt/P26.txt ##
#
# Cowie v. Draper, [2010] B.C.J. No. 910
# ## Processing ../data/Lexis Cases txt/P27.txt ##
#
# Thiessen v. Mutual Life Assurance Co. of Canada, [2001] B.C.J. No. 1849
# Matches:
# [(0.9681528662420382, ' loss of $145,000')]
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P28.txt ##
#
# Strata Plan NW 3341 v. Canlan Ice Sports Corp., [2001] B.C.J. No. 1723
# Matches:
# [(0.9949238578680203, 'total damages, $3,151,572.65'), (0.9644670050761421, 'total damages, $3,151,572.65')]
# defaultdict(<class 'float'>, {'Special': 0.0, 'General': 3151572.65, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 0.0, 'Non-pecuniary': 0.0, 'Total': 3151572.65})
# ## Processing ../data/Lexis Cases txt/P29.txt ##
#
# Mardones v. Toyota Credit Canada Inc., [2008] B.C.J. No. 1217
# Matches:
# [(0.9158878504672897, '$12,000 in non-pecuniary damages'), (0.9158878504672897, 'awarded $12,000'), (0.8598130841121495, '$50,000 in non-pecuniary damages'), (0.8598130841121495, 'awarded $50,000')]
# defaultdict(<class 'float'>, {'Non-pecuniary': 12000.0, 'Special': 0.0, 'General': 0.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 0.0, 'Total': 12000.0})
# ## Processing ../data/Lexis Cases txt/P30.txt ##
#
# Bjornson v. Field, [2007] B.C.J. No. 2734
# Matches:
# [(0.9850746268656716, 'general damage: $110,000.00'), (0.9850746268656716, 'wage loss: 18,000.00'), (0.9850746268656716, 'wage loss: 20,000.00'), (0.9850746268656716, 'Special Damages: 11,738.72'), (0.9850746268656716, 'Past wage loss: 18,000.00'), (0.9850746268656716, 'Future wage loss: 20,000.00'), (0.9850746268656716, 'future care: 60,000.00'), (0.9253731343283582, 'future services in the sum of $50,000'), (0.8656716417910447, 'this loss at $4,000')]
# defaultdict(<class 'float'>, {'General': 130000.0, 'Special': 29738.72, 'Future Care': 60000.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Pecuniary Total': 219738.72, 'Non-pecuniary': 0.0, 'Total': 219738.72})
# ## Processing ../data/Lexis Cases txt/P31.txt ##
# Tabori v. Renaud, [2016] B.C.J. No. 1424
# ## Processing ../data/Lexis Cases txt/P32.txt ##
#
# Maruna v. Lopatka, [2001] B.C.J. No. 484
# ## Processing ../data/Lexis Cases txt/P33.txt ##
#
# Cresswell Investments Ltd. v. Pavone, [2011] B.C.J. No. 1523
# ## Processing ../data/Lexis Cases txt/P34.txt ##
#
# Drucker, Inc. v. Gui, [2009] B.C.J. No. 808
# Matches:
# [(0.967741935483871, '$5,000 in punitive damages'), (0.967741935483871, 'award $5,000')]
# defaultdict(<class 'float'>, {'Punitive': 5000.0, 'Special': 0.0, 'General': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 5000.0, 'Non-pecuniary': 0.0, 'Total': 5000.0})
# ## Processing ../data/Lexis Cases txt/P35.txt ##
#
# Bell v. Thorner, [2009] B.C.J. No. 63
# ## Processing ../data/Lexis Cases txt/P36.txt ##
#
# ## Processing ../data/Lexis Cases txt/P37.txt ##
#
# Thom v. Laird Custom Homes Ltd., [2017] B.C.J. No. 1762
# ## Processing ../data/Lexis Cases txt/P38.txt ##
#
# Aldred v. Colbeck, [2010] B.C.J. No. 89
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P39.txt ##
#
# Hollingworth v. Herron Estate, [2005] B.C.J. No. 772
# ## Processing ../data/Lexis Cases txt/P40.txt ##
#
# Gill v. Canada (Minister of Transport), [2014] B.C.J. No. 594
# ## Processing ../data/Lexis Cases txt/P41.txt ##
#
# Provencher v. St. Paul's Hospital, [2015] B.C.J. No. 1113
# Matches:
# [(0.9740932642487047, 'Non-pecuniary Damages: $35,000'), (0.9740932642487047, 'Future Care: $4,000'), (0.9326424870466321, 'award in the amount of $4,000')]
# defaultdict(<class 'float'>, {'Non-pecuniary': 35000.0, 'Future Care': 4000.0, 'Special': 0.0, 'General': 0.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Pecuniary Total': 4000.0, 'Total': 39000.0})
# ## Processing ../data/Lexis Cases txt/P42.txt ##
#
# Li v. Ouyang, [2012] B.C.J. No. 66
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P43.txt ##
#
# Moore v. Walker, [2001] B.C.J. No. 1563
# ## Processing ../data/Lexis Cases txt/P44.txt ##
#
# Fillion (Guardian ad litem of) v. Balko, [2003] B.C.J. No. 621
# Matches:
# [(0.9743589743589743, 'net damages in the amount of $18,000'), (0.9572649572649573, '$22,000 representing non-pecuniary damages'), (0.9572649572649573, '$500 representing special damages'), (0.9401709401709402, '$500 to the plaintiff for special damages')]
# defaultdict(<class 'float'>, {'Non-pecuniary': 22000.0, 'Special': 500.0, 'General': 0.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 500.0, 'Total': 22500.0})
# ## Processing ../data/Lexis Cases txt/P45.txt ##
#
# Silver Bullet Contracting Ltd. v. Roba Holdings Inc., [2000] B.C.J. No. 1844
# ## Processing ../data/Lexis Cases txt/P46.txt ##
#
# B.S.A. Investors Ltd. v. Mosly, [2005] B.C.J. No. 1061
# ## Processing ../data/Lexis Cases txt/P47.txt ##
#
# Whalley v. Splashdown Waterparks Inc., [2005] B.C.J. No. 1370
# ## Processing ../data/Lexis Cases txt/P48.txt ##
#
# Geremia v. Nielsen Estate, [2006] B.C.J. No. 321
# ## Processing ../data/Lexis Cases txt/P49.txt ##
#
# Miller v. Budzinski, [2003] B.C.J. No. 1918
# ## Processing ../data/Lexis Cases txt/P50.txt ##
#
# Day v. Roberts, [2019] B.C.J. No. 2205
# Matches:
# [(0.9942418426103646, 'Non-pecuniary damages $120,000'), (0.9942418426103646, 'wage loss $72,190.75'), (0.9942418426103646, 'Future loss of earning capacity $180,000'), (0.9942418426103646, 'Special damages $2,269.33'), (0.9942418426103646, 'Past wage loss $72,190.75'), (0.9942418426103646, 'Future loss of earning capacity $180,000'), (0.9942418426103646, 'future care $15,400'), (0.963531669865643, 'future care is $15,382.67'), (0.9328214971209213, 's loss of future earning capacity to be $180,000'), (0.9328214971209213, 'future earning capacity to be $180,000')]
# defaultdict(<class 'float'>, {'Non-pecuniary': 120000.0, 'General': 180000.0, 'Special': 74460.08, 'Future Care': 15400.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Pecuniary Total': 269860.08, 'Total': 389860.08})
# ## Processing ../data/Lexis Cases txt/P51.txt ##
#
# Gearbulk Pool Ltd. v. Seaboard Shipping Co. (c.o.b. Seaboard International Shipping Co.), [2005] B.C.J. No. 2518
# ## Processing ../data/Lexis Cases txt/P52.txt ##
#
# Douez v. Facebook, Inc., [2014] B.C.J. No. 1051
# ## Processing ../data/Lexis Cases txt/P53.txt ##
#
# Miquelon Properties Ltd. v. Squamish (District), [2001] B.C.J. No. 884
# Matches:
# [(0.9491525423728814, 'any damages it has suffered but for the $30,909.55')]
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P54.txt ##
#
# Pang v. Dhalla, [2011] B.C.J. No. 813
# Matches:
# [(0.9361702127659575, 'Special damages are awarded in the amount of $1,918'), (0.9361702127659575, 'awarded in the amount of $1,918')]
# defaultdict(<class 'float'>, {'Special': 1918.0, 'General': 0.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 1918.0, 'Non-pecuniary': 0.0, 'Total': 1918.0})
# ## Processing ../data/Lexis Cases txt/P55.txt ##
#
# Toronto-Dominion Bank v. Jones, [2001] B.C.J. No. 1864
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P56.txt ##
#
# Clare's Cove Marina Ltd. v. Salmon Arm (City), [2013] B.C.J. No. 624
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P57.txt ##
#
# Dhillon v. Singer, [2017] B.C.J. No. 496
# Matches:
# [(0.9975429975429976, 'past loss of income from March 19, 2010'), (0.9975429975429976, 'wage loss during that period therefore was $8,670'), (0.9975429975429976, 'past loss of earning capacity includes $30,959.21'), (0.9975429975429976, 'past loss of earning capacity: $30,959.21'), (0.9975429975429976, '$9,360 in damages'), (0.9975429975429976, '$9,360 in damages'), (0.9975429975429976, 'past loss of income from March 19, 2010'), (0.9975429975429976, 'past loss of earning capacity includes $30,959.21'), (0.9975429975429976, 'past loss of earning capacity: $30,959.21'), (0.9926289926289926, 'non-pecuniary damages: $85,000'), (0.9926289926289926, 'past loss of earning capacity: $30,959.21'), (0.9926289926289926, 'future loss of capacity: $46,740'), (0.9926289926289926, 'loss of housekeeping capacity: $11,000'), (0.9926289926289926, 'special damages: $5,752.77'), (0.9926289926289926, '$9,360 in damages'), (0.9926289926289926, 'past loss of earning capacity: $30,959.21'), (0.9926289926289926, 'future loss of capacity: $46,740'), (0.9926289926289926, 'future care: $17,475.50'), (0.972972972972973, 'award of $11,000'), (0.9484029484029484, "future. The plaintiff's estimate for annual prescription expenses of $750"), (0.9484029484029484, 'award for the cost of future care of $17,475.50'), (0.8894348894348895, 'earning capacity has an annual value of $30,784'), (0.8894348894348895, 'annual loss of $2,496'), (0.855036855036855, 'past loss of earning capacity includes $30,959.21'), (0.855036855036855, '$9,360 in damages'), (0.855036855036855, 'past loss of earning capacity includes $30,959.21'), (0.8501228501228502, 'pecuniary loss of $9,360')]
# defaultdict(<class 'float'>, {'Special': 5771.77, 'General': 30959.21, 'Non-pecuniary': 85000.0, 'Future Care': 17475.5, 'Punitive': 0.0, 'Aggravated': 0.0, 'Pecuniary Total': 54206.479999999996, 'Total': 139206.47999999998})
# ## Processing ../data/Lexis Cases txt/P58.txt ##
#
# Beaver Lake Industrial Park Inc. v. Kelowna (City), [2006] B.C.J. No. 654
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P59.txt ##
#
# Canadian Maritime Engineering Ltd. v. British Columbia Ferry Services Inc., [2013] B.C.J. No. 1375
# ## Processing ../data/Lexis Cases txt/P60.txt ##
#
# McCartney v. Rawlins, [2000] B.C.J. No. 1340
# Matches:
# [(0.9041095890410958, 'Non-pecuniary loss $51,000'), (0.9041095890410958, 'earning capacity $25,000'), (0.9041095890410958, 'Special damages $3,230'), (0.9041095890410958, 'Future care $5,525')]
# defaultdict(<class 'float'>, {'Non-pecuniary': 51000.0, 'General': 25000.0, 'Special': 3230.0, 'Future Care': 5525.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Pecuniary Total': 33755.0, 'Total': 84755.0})
# ## Processing ../data/Lexis Cases txt/P61.txt ##
#
# Sonmor (Guardian ad Litem of) v. Williams, [2006] B.C.J. No. 1744
# ## Processing ../data/Lexis Cases txt/P62.txt ##
#
# Grahovac v. Hartfiel, [2015] B.C.J. No. 1494
# ## Processing ../data/Lexis Cases txt/P63.txt ##
# Budget Rent a Car System, Inc. v. Philadelphia Indemnity Insurance Co., [2018] B.C.J. No. 165
# ## Processing ../data/Lexis Cases txt/P64.txt ##
#
# Home Equity Development Inc. v. Crow, [2002] B.C.J. No. 3169
# ## Processing ../data/Lexis Cases txt/P65.txt ##
#
# Woods v. Plewes, [2014] B.C.J. No. 350
# ## Processing ../data/Lexis Cases txt/P66.txt ##
#
# R.G. v. Vancouver (City) Police Board, [2012] B.C.J. No. 62
# ## Processing ../data/Lexis Cases txt/P67.txt ##
#
# Mutual Construction (2000) Ltd. v. Hardwick, [2009] B.C.J. No. 183
# ## Processing ../data/Lexis Cases txt/P68.txt ##
#
# 336332 B.C. Ltd. v. Imperial Oil Ltd., [2002] B.C.J. No. 844
# ## Processing ../data/Lexis Cases txt/P69.txt ##
#
# Mann v. Kathuria, [2017] B.C.J. No. 2462
# ## Processing ../data/Lexis Cases txt/P70.txt ##
#
# Lenning v. Hicks, [2014] B.C.J. No. 1272
# ## Processing ../data/Lexis Cases txt/P71.txt ##
#
# Cornish v. Khunkhun, [2015] B.C.J. No. 1014
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P72.txt ##
#
# Doerksen v. First Open Heart Society of British Columbia (c.o.b. Heart House), [2010] B.C.J. No. 1811
# ## Processing ../data/Lexis Cases txt/P73.txt ##
#
# Vince Estate v. Christian Reformed Seniors Housing Society, [2002] B.C.J. No. 2244
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P74.txt ##
#
# Hunter v. Granger, [2009] B.C.J. No. 2944
# ## Processing ../data/Lexis Cases txt/P75.txt ##
#
# 0782484 B.C. Ltd. v. E-Pro Enterprises Inc., [2017] B.C.J. No. 2485
# ## Processing ../data/Lexis Cases txt/P76.txt ##
#
# Mordo v. Nitting, [2006] B.C.J. No. 3081
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P77.txt ##
#
# Sartori v. Gates, [2011] B.C.J. No. 616
# Matches:
# []
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P78.txt ##
#
# Perrick v. RJS Electrical Contracting Ltd., [2020] B.C.J. No. 244
# Matches:
# [(0.8982035928143712, 'suffered damages of $427,288.08'), (0.8982035928143712, 'Special damages of $52,288.08')]
# defaultdict(<class 'float'>, {'Special': 52288.08, 'General': 0.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Future Care': 0.0, 'Pecuniary Total': 52288.08, 'Non-pecuniary': 0.0, 'Total': 52288.08})
# ## Processing ../data/Lexis Cases txt/P79.txt ##
#
# Anakotta v. Perusini, [2004] B.C.J. No. 270
# Matches:
# [(0.893740902474527, 'capital loss therefore is $30,000'), (0.893740902474527, 'capital loss of $18,200'), (0.8733624454148472, 'capital loss associated with User Area No. 151'), (0.8558951965065502, 'capital loss in the amount of $19,060')]
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# ## Processing ../data/Lexis Cases txt/P80.txt ##
#
# ## Processing ../data/Lexis Cases txt/P81.txt ##
#
# Scott v. Collins, [2007] B.C.J. No. 1182
# ## Processing ../data/Lexis Cases txt/P82.txt ##
#
# Sahota v. Slupskyy, [2019] B.C.J. No. 2512
# Matches:
# [(0.9326683291770573, 'Non-pecuniary damages - $75,000'), (0.9326683291770573, 'Past Loss of Earning Capacity - $73,000'), (0.9326683291770573, 'Loss of Future Earning Capacity - $115,000'), (0.9326683291770573, 'Special Damages - $4,703'), (0.9326683291770573, 'Past Loss of Earning Capacity - $73,000'), (0.9326683291770573, 'Future Earning Capacity - $115,000'), (0.9326683291770573, 'Future Care - $4,000'), (0.9276807980049875, 'award in the amount of $4,000')]
# defaultdict(<class 'float'>, {'Non-pecuniary': 75000.0, 'General': 188000.0, 'Special': 4703.0, 'Future Care': 4000.0, 'Punitive': 0.0, 'Aggravated': 0.0, 'Pecuniary Total': 196703.0, 'Total': 271703.0})
# ## Processing ../data/Lexis Cases txt/P83.txt ##
#
# McLaren v. Rice, [2008] B.C.J. No. 2648
# ## Processing ../data/Lexis Cases txt/P84.txt ##
#
# ## Processing ../data/Lexis Cases txt/P85.txt ##
#
# Musqueam Indian Band Board of Review v. Musqueam Indian Band, [2013] B.C.J. No. 1672
# Matches:
# [(0.9966329966329966, 'DAMAGES [p. 430'), (0.9966329966329966, 'of damages." [p. 437'), (0.9966329966329966, 'the damage loss estimates calculated by the plaintiffs." [p. 439'), (0.9966329966329966, ' damages at $ 10,000,000'), (0.9966329966329966, 'exemplary damages." [p. 443'), (0.9966329966329966, 'The damages are assessed at $10,000,000'), (0.9966329966329966, 'of Damages [p. 356'), (0.9966329966329966, 'future." [p. 396'), (0.9966329966329966, 'future." [p. 409'), (0.9966329966329966, 'future." [p. 347')]
# defaultdict(<class 'float'>, {'Special': None, 'General': None, 'Punitive': None, 'Aggravated': None, 'Future Care': None, 'Pecuniary Total': None, 'Non-pecuniary': None, 'Total': None})
# Total cases being used: 80

# %%
data
# Out:
# [{'case_title': 'Mawani v. Pitcairn, [2012] B.C.J. No. 1819',
#   'year': '2012',
#   'registry': 'Vancouver',
#   'judge': 'S.F. Kelleher J.',
#   'decision_length': '115',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Brooks-Martin v. Martin, [2011] B.C.J. No. 243',
#   'year': '2011',
#   'registry': 'Nanaimo',
#   'judge': 'D.A. Halfyard J.',
#   'decision_length': '172',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'McGavin v. Talbot, [2017] B.C.J. No. 2439',
#   'year': '2017',
#   'registry': 'Victoria',
#   'judge': 'D.M. Masuhara J.',
#   'decision_length': '59',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'General': 72000.0,
#                'Special': 16536.82,
#                'Future Care': 9900.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Pecuniary Total': 98436.82,
#                'Non-pecuniary': 0.0,
#                'Total': 98436.82})},
#  {'case_title': 'Mclaren v. Rice, [2009] B.C.J. No. 2108',
#   'year': '2009',
#   'registry': 'Vancouver',
#   'judge': 'T.R. Brooke J.',
#   'decision_length': '46',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Jacobs v. Basil, [2017] B.C.J. No. 1517',
#   'year': '2017',
#   'registry': 'Vernon',
#   'judge': 'P. Abrioux J.',
#   'decision_length': '229',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'General': 130000.0,
#                'Special': 0.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 50000.0,
#                'Pecuniary Total': 180000.0,
#                'Non-pecuniary': 0.0,
#                'Total': 180000.0})},
#  {'case_title': 'Jackson v. Fisheries and Oceans Canada, [2006] B.C.J. No. 2654',
#   'year': '2006',
#   'registry': 'Prince Rupert',
#   'judge': 'Halfyard J.',
#   'decision_length': '38',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Brito (Guardian ad litem of) v. Woolley, [2001] B.C.J. No. 1692',
#   'year': '2001',
#   'registry': 'Vancouver',
#   'judge': 'Sinclair Prowse J.',
#   'decision_length': '694',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': 381374.0,
#                'General': 864661.21,
#                'Non-pecuniary': 260000.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 1246035.21,
#                'Total': 1506035.21})},
#  {'case_title': 'Rackstraw (Litigation guardian of) v. Robertson, [2011] B.C.J. No. 1354',
#   'year': '2011',
#   'registry': 'Vancouver',
#   'judge': 'B. Fisher J.',
#   'decision_length': '38',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Intrawest Corp. v. Hart, [2002] B.C.J. No. 301',
#   'year': '2002',
#   'registry': 'Vancouver',
#   'judge': 'Melnick J.',
#   'decision_length': '76',
#   'multiple_defendants': 'N',
#   'damages': defaultdict(float,
#               {'Special': 0.0,
#                'General': 353519.11,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 0.0,
#                'Non-pecuniary': 0.0,
#                'Total': 353519.11})},
#  {'case_title': 'Millard v. Singleton, [2015] B.C.J. No. 1234',
#   'year': '2015',
#   'registry': 'Vancouver',
#   'judge': 'N. Sharma J.',
#   'decision_length': '70',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'C.H. v. British Columbia, [2003] B.C.J. No. 1706',
#   'year': '2003',
#   'registry': 'Victoria',
#   'judge': 'Owen-Flood J.',
#   'decision_length': '234',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'General': 127500.0,
#                'Aggravated': 10000.0,
#                'Special': 0.0,
#                'Punitive': 0.0,
#                'Future Care': 15000.0,
#                'Pecuniary Total': 152500.0,
#                'Non-pecuniary': 0.0,
#                'Total': 152500.0})},
#  {'case_title': 'N&C Transportation Ltd. v. Navistar International Corp., [2016] B.C.J. No. 2369',
#   'year': '2016',
#   'registry': 'Vancouver',
#   'judge': 'R.A. Skolrood J.',
#   'decision_length': '195',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Aiken (Guardian ad litem of) v. Van Dyk, [2001] B.C.J. No. 1751',
#   'year': '2001',
#   'registry': 'Mile House',
#   'judge': 'Powers J.',
#   'decision_length': '54',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Ahlwat v. Green, [2014] B.C.J. No. 2452',
#   'year': '2014',
#   'registry': 'Vancouver',
#   'judge': 'N. Sharma J.',
#   'decision_length': '50',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Logeman v. Rossa, [2006] B.C.J. No. 963',
#   'year': '2006',
#   'registry': 'Vancouver',
#   'judge': 'Sinclair Prowse J.',
#   'decision_length': '86',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Ellis (Litigation guardian of) v. Duong, [2017] B.C.J. No. 546',
#   'year': '2017',
#   'registry': 'Vancouver',
#   'judge': 'W.J. Harris J.',
#   'decision_length': '217',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Non-pecuniary': 220000.0,
#                'General': 730000.0,
#                'Special': 6074.19,
#                'Future Care': 222360.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Pecuniary Total': 958434.19,
#                'Total': 1178434.19})},
#  {'case_title': 'Los Angeles Salad Co. v. Canadian Food Inspection Agency, [2009] B.C.J. No. 161',
#   'year': '2009',
#   'registry': 'Vancouver',
#   'judge': 'D.J. Martinson J.',
#   'decision_length': '31',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Harder v. Poettcker, [2015] B.C.J. No. 2579',
#   'year': '2015',
#   'registry': 'Vancouver',
#   'judge': 'J.S. Sigurdson J.',
#   'decision_length': '26',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Fabian v. Song, [2018] B.C.J. No. 896',
#   'year': '2018',
#   'registry': 'Vancouver',
#   'judge': 'M. Morellato J.',
#   'decision_length': '138',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': 4599.25,
#                'General': 36000.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 3000.0,
#                'Pecuniary Total': 43599.25,
#                'Non-pecuniary': 70000.0,
#                'Total': 113599.25})},
#  {'case_title': 'Fichtner v. Johnston Meier Insurance Services Ltd., [2001] B.C.J. No. 1666',
#   'year': '2001',
#   'registry': 'Vancouver',
#   'judge': 'Slade J.',
#   'decision_length': '51',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Dr. Andrew Hokhold Inc. v. Wells (c.o.b. Spall Machine & Welding), [2005] B.C.J. No. 255',
#   'year': '2005',
#   'registry': 'Vernon',
#   'judge': 'Bennett J.',
#   'decision_length': '87',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Paniccia v. Eckert, [2012] B.C.J. No. 1997',
#   'year': '2012',
#   'registry': 'Penticton',
#   'judge': 'G. Barrow J.',
#   'decision_length': '138',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': 0.0,
#                'General': 6037.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 0.0,
#                'Non-pecuniary': 0.0,
#                'Total': 6037.0})},
#  {'case_title': 'Austin v. Joaquin, [2007] B.C.J. No. 1894',
#   'year': '2007',
#   'registry': 'Vancouver',
#   'judge': 'Slade J.',
#   'decision_length': '67',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Cowie v. Draper, [2010] B.C.J. No. 910',
#   'year': '2010',
#   'registry': 'Vancouver',
#   'judge': 'T.W. Bowden J.',
#   'decision_length': '58',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Thiessen v. Mutual Life Assurance Co. of Canada, [2001] B.C.J. No. 1849',
#   'year': '2001',
#   'registry': 'Chilliwack',
#   'judge': 'Ross J.',
#   'decision_length': '78',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Strata Plan NW 3341 v. Canlan Ice Sports Corp., [2001] B.C.J. No. 1723',
#   'year': '2001',
#   'registry': 'Vancouver',
#   'judge': 'Grist J.',
#   'decision_length': '98',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': 0.0,
#                'General': 3151572.65,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 0.0,
#                'Non-pecuniary': 0.0,
#                'Total': 3151572.65})},
#  {'case_title': 'Mardones v. Toyota Credit Canada Inc., [2008] B.C.J. No. 1217',
#   'year': '2008',
#   'registry': 'New Westminster',
#   'judge': 'J.E.D. Savage J.',
#   'decision_length': '53',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Non-pecuniary': 12000.0,
#                'Special': 0.0,
#                'General': 0.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 0.0,
#                'Total': 12000.0})},
#  {'case_title': 'Bjornson v. Field, [2007] B.C.J. No. 2734',
#   'year': '2007',
#   'registry': 'Powell River',
#   'judge': 'W.G.E. Grist J.',
#   'decision_length': '33',
#   'multiple_defendants': 'N',
#   'damages': defaultdict(float,
#               {'General': 130000.0,
#                'Special': 29738.72,
#                'Future Care': 60000.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Pecuniary Total': 219738.72,
#                'Non-pecuniary': 0.0,
#                'Total': 219738.72})},
#  {'case_title': 'Tabori v. Renaud, [2016] B.C.J. No. 1424',
#   'year': '2016',
#   'registry': 'New Westminster',
#   'judge': 'M.M. Devlin J.',
#   'decision_length': '50',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Maruna v. Lopatka, [2001] B.C.J. No. 484',
#   'year': '2001',
#   'registry': 'Vancouver',
#   'judge': 'Melvin J.',
#   'decision_length': '25',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Cresswell Investments Ltd. v. Pavone, [2011] B.C.J. No. 1523',
#   'year': '2011',
#   'registry': 'Vancouver',
#   'judge': 'N.H. Smith J.',
#   'decision_length': '56',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Drucker, Inc. v. Gui, [2009] B.C.J. No. 808',
#   'year': '2009',
#   'registry': 'Vancouver',
#   'judge': 'E.M. Meyers J.',
#   'decision_length': '139',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Punitive': 5000.0,
#                'Special': 0.0,
#                'General': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 5000.0,
#                'Non-pecuniary': 0.0,
#                'Total': 5000.0})},
#  {'case_title': 'Bell v. Thorner, [2009] B.C.J. No. 63',
#   'year': '2009',
#   'registry': 'Vancouver',
#   'judge': 'M.A. Humphries J.',
#   'decision_length': '39',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Thom v. Laird Custom Homes Ltd., [2017] B.C.J. No. 1762',
#   'year': '2017',
#   'registry': 'Vancouver',
#   'judge': 'J.W. Williams J.',
#   'decision_length': '67',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Aldred v. Colbeck, [2010] B.C.J. No. 89',
#   'year': '2010',
#   'registry': 'Vancouver',
#   'judge': 'I.H. Pitfield J.',
#   'decision_length': '89',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Hollingworth v. Herron Estate, [2005] B.C.J. No. 772',
#   'year': '2005',
#   'registry': 'Prince George',
#   'judge': 'Master Baker',
#   'decision_length': '19',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Gill v. Canada (Minister of Transport), [2014] B.C.J. No. 594',
#   'year': '2014',
#   'registry': 'Vancouver',
#   'judge': 'B.M. Greyell J.',
#   'decision_length': '206',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': "Provencher v. St. Paul's Hospital, [2015] B.C.J. No. 1113",
#   'year': '2015',
#   'registry': 'Vancouver',
#   'judge': 'D.J. Dardi J.',
#   'decision_length': '96',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Non-pecuniary': 35000.0,
#                'Future Care': 4000.0,
#                'Special': 0.0,
#                'General': 0.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Pecuniary Total': 4000.0,
#                'Total': 39000.0})},
#  {'case_title': 'Li v. Ouyang, [2012] B.C.J. No. 66',
#   'year': '2012',
#   'registry': 'Vancouver',
#   'judge': 'R.E. Powers J.',
#   'decision_length': '53',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Moore v. Walker, [2001] B.C.J. No. 1563',
#   'year': '2001',
#   'registry': 'Kamloops',
#   'judge': 'Kirkpatrick J.',
#   'decision_length': '77',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Fillion (Guardian ad litem of) v. Balko, [2003] B.C.J. No. 621',
#   'year': '2003',
#   'registry': 'Prince George',
#   'judge': 'Chamberlist J. (In Chambers)',
#   'decision_length': '58',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Non-pecuniary': 22000.0,
#                'Special': 500.0,
#                'General': 0.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 500.0,
#                'Total': 22500.0})},
#  {'case_title': 'Silver Bullet Contracting Ltd. v. Roba Holdings Inc., [2000] B.C.J. No. 1844',
#   'year': '2000',
#   'registry': 'Nanaimo',
#   'judge': 'R.M.J. Hutchinson J.',
#   'decision_length': '17',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'B.S.A. Investors Ltd. v. Mosly, [2005] B.C.J. No. 1061',
#   'year': '2005',
#   'registry': 'Vancouver',
#   'judge': 'Williamson J.',
#   'decision_length': '26',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Whalley v. Splashdown Waterparks Inc., [2005] B.C.J. No. 1370',
#   'year': '2005',
#   'registry': 'New Westminster',
#   'judge': 'McKinnon J.',
#   'decision_length': '48',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Geremia v. Nielsen Estate, [2006] B.C.J. No. 321',
#   'year': '2006',
#   'registry': 'Vernon',
#   'judge': 'Rogers J.',
#   'decision_length': '21',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Miller v. Budzinski, [2003] B.C.J. No. 1918',
#   'year': '2003',
#   'registry': 'New Westminster',
#   'judge': 'Preston J.',
#   'decision_length': '26',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Day v. Roberts, [2019] B.C.J. No. 2205',
#   'year': '2019',
#   'registry': 'Vancouver',
#   'judge': 'D.C. MacDonald J.',
#   'decision_length': '260',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Non-pecuniary': 120000.0,
#                'General': 180000.0,
#                'Special': 74460.08,
#                'Future Care': 15400.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Pecuniary Total': 269860.08,
#                'Total': 389860.08})},
#  {'case_title': 'Gearbulk Pool Ltd. v. Seaboard Shipping Co. (c.o.b. Seaboard International Shipping Co.), [2005] B.C.J. No. 2518',
#   'year': '2005',
#   'registry': 'Vancouver',
#   'judge': 'Cohen J.',
#   'decision_length': '116',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Douez v. Facebook, Inc., [2014] B.C.J. No. 1051',
#   'year': '2014',
#   'registry': 'Vancouver',
#   'judge': 'S.A. Griffin J.',
#   'decision_length': '370',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Miquelon Properties Ltd. v. Squamish (District), [2001] B.C.J. No. 884',
#   'year': '2001',
#   'registry': 'Vancouver',
#   'judge': 'Loo J.',
#   'decision_length': '29',
#   'multiple_defendants': 'N',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Pang v. Dhalla, [2011] B.C.J. No. 813',
#   'year': '2011',
#   'registry': 'Vancouver',
#   'judge': 'J.R. Dillon J.',
#   'decision_length': '23',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': 1918.0,
#                'General': 0.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 1918.0,
#                'Non-pecuniary': 0.0,
#                'Total': 1918.0})},
#  {'case_title': 'Toronto-Dominion Bank v. Jones, [2001] B.C.J. No. 1864',
#   'year': '2001',
#   'registry': 'Vancouver',
#   'judge': 'Satanove J.',
#   'decision_length': '42',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': "Clare's Cove Marina Ltd. v. Salmon Arm (City), [2013] B.C.J. No. 624",
#   'year': '2013',
#   'registry': 'Kamloops',
#   'judge': 'G. Barrow J.',
#   'decision_length': '216',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Dhillon v. Singer, [2017] B.C.J. No. 496',
#   'year': '2017',
#   'registry': 'Vancouver',
#   'judge': 'M.L. Fleming J.',
#   'decision_length': '203',
#   'multiple_defendants': 'N',
#   'damages': defaultdict(float,
#               {'Special': 5771.77,
#                'General': 30959.21,
#                'Non-pecuniary': 85000.0,
#                'Future Care': 17475.5,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Pecuniary Total': 54206.479999999996,
#                'Total': 139206.47999999998})},
#  {'case_title': 'Beaver Lake Industrial Park Inc. v. Kelowna (City), [2006] B.C.J. No. 654',
#   'year': '2006',
#   'registry': 'Vancouver',
#   'judge': 'Silverman J.',
#   'decision_length': '145',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Canadian Maritime Engineering Ltd. v. British Columbia Ferry Services Inc., [2013] B.C.J. No. 1375',
#   'year': '2013',
#   'registry': 'Victoria',
#   'judge': 'D. Thompson J.',
#   'decision_length': '34',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'McCartney v. Rawlins, [2000] B.C.J. No. 1340',
#   'year': '2000',
#   'registry': 'Vancouver',
#   'judge': 'Lowry J.',
#   'decision_length': '36',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Non-pecuniary': 51000.0,
#                'General': 25000.0,
#                'Special': 3230.0,
#                'Future Care': 5525.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Pecuniary Total': 33755.0,
#                'Total': 84755.0})},
#  {'case_title': 'Sonmor (Guardian ad Litem of) v. Williams, [2006] B.C.J. No. 1744',
#   'year': '2006',
#   'registry': 'Vancouver',
#   'judge': 'Preston J. (In Chambers)',
#   'decision_length': '18',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Grahovac v. Hartfiel, [2015] B.C.J. No. 1494',
#   'year': '2015',
#   'registry': 'Vancouver',
#   'judge': 'S.A. Griffin J.',
#   'decision_length': '87',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Budget Rent a Car System, Inc. v. Philadelphia Indemnity Insurance Co., [2018] B.C.J. No. 165',
#   'year': '2018',
#   'registry': 'Vancouver',
#   'judge': 'N. Sharma J.',
#   'decision_length': '164',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Home Equity Development Inc. v. Crow, [2002] B.C.J. No. 3169',
#   'year': '2002',
#   'registry': 'Victoria',
#   'judge': 'Quijano J.',
#   'decision_length': '24',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Woods v. Plewes, [2014] B.C.J. No. 350',
#   'year': '2014',
#   'registry': 'Victoria',
#   'judge': 'M.D. Macaulay J.',
#   'decision_length': '94',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'R.G. v. Vancouver (City) Police Board, [2012] B.C.J. No. 62',
#   'year': '2012',
#   'registry': 'Vancouver',
#   'judge': 'G.D. Burnyeat J.',
#   'decision_length': '46',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Mutual Construction (2000) Ltd. v. Hardwick, [2009] B.C.J. No. 183',
#   'year': '2000',
#   'registry': 'Vancouver',
#   'judge': 'A.W. MacKenzie J.',
#   'decision_length': '66',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': '336332 B.C. Ltd. v. Imperial Oil Ltd., [2002] B.C.J. No. 844',
#   'year': '2002',
#   'registry': 'Vancouver',
#   'judge': 'Ross J.',
#   'decision_length': '82',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Mann v. Kathuria, [2017] B.C.J. No. 2462',
#   'year': '2017',
#   'registry': 'Vancouver',
#   'judge': 'L.B. Gerow J.',
#   'decision_length': '21',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Lenning v. Hicks, [2014] B.C.J. No. 1272',
#   'year': '2014',
#   'registry': 'Vancouver',
#   'judge': 'R.S. Tindale J.',
#   'decision_length': '45',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Cornish v. Khunkhun, [2015] B.C.J. No. 1014',
#   'year': '2015',
#   'registry': 'Vancouver',
#   'judge': 'R.A. Skolrood J.',
#   'decision_length': '70',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Doerksen v. First Open Heart Society of British Columbia (c.o.b. Heart House), [2010] B.C.J. No. 1811',
#   'year': '2010',
#   'registry': 'Victoria',
#   'judge': 'R.D. Wilson J.',
#   'decision_length': '93',
#   'multiple_defendants': 'N',
#   'damages': None},
#  {'case_title': 'Vince Estate v. Christian Reformed Seniors Housing Society, [2002] B.C.J. No. 2244',
#   'year': '2002',
#   'registry': 'Vancouver',
#   'judge': 'Melnick J.',
#   'decision_length': '13',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Hunter v. Granger, [2009] B.C.J. No. 2944',
#   'year': '2009',
#   'registry': 'Vancouver',
#   'judge': 'G.R.J. Gaul J.',
#   'decision_length': '41',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': '0782484 B.C. Ltd. v. E-Pro Enterprises Inc., [2017] B.C.J. No. 2485',
#   'year': '2017',
#   'registry': 'Victoria',
#   'judge': 'P.G. Voith J.',
#   'decision_length': '74',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Mordo v. Nitting, [2006] B.C.J. No. 3081',
#   'year': '2006',
#   'registry': 'Vancouver',
#   'judge': 'Wedge J.',
#   'decision_length': '500',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Sartori v. Gates, [2011] B.C.J. No. 616',
#   'year': '2011',
#   'registry': 'Victoria',
#   'judge': 'R.D. Wilson J.',
#   'decision_length': '106',
#   'multiple_defendants': 'N',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Perrick v. RJS Electrical Contracting Ltd., [2020] B.C.J. No. 244',
#   'year': '2020',
#   'registry': 'Vancouver',
#   'judge': 'G.B. Gomery J. (In Chambers)',
#   'decision_length': '83',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': 52288.08,
#                'General': 0.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Future Care': 0.0,
#                'Pecuniary Total': 52288.08,
#                'Non-pecuniary': 0.0,
#                'Total': 52288.08})},
#  {'case_title': 'Anakotta v. Perusini, [2004] B.C.J. No. 270',
#   'year': '2004',
#   'registry': 'Vernon',
#   'judge': 'Barrow J.',
#   'decision_length': '343',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})},
#  {'case_title': 'Scott v. Collins, [2007] B.C.J. No. 1182',
#   'year': '2007',
#   'registry': 'Vancouver',
#   'judge': 'Brooke J. (In Chambers)',
#   'decision_length': '21',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Sahota v. Slupskyy, [2019] B.C.J. No. 2512',
#   'year': '2019',
#   'registry': 'New Westminster',
#   'judge': 'N.P. Kent J.',
#   'decision_length': '200',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Non-pecuniary': 75000.0,
#                'General': 188000.0,
#                'Special': 4703.0,
#                'Future Care': 4000.0,
#                'Punitive': 0.0,
#                'Aggravated': 0.0,
#                'Pecuniary Total': 196703.0,
#                'Total': 271703.0})},
#  {'case_title': 'McLaren v. Rice, [2008] B.C.J. No. 2648',
#   'year': '2008',
#   'registry': 'Vancouver',
#   'judge': 'T.R. Brooke J.',
#   'decision_length': '9',
#   'multiple_defendants': 'Y',
#   'damages': None},
#  {'case_title': 'Musqueam Indian Band Board of Review v. Musqueam Indian Band, [2013] B.C.J. No. 1672',
#   'year': '2013',
#   'registry': 'Vancouver',
#   'judge': 'M.A. Maisonville J.',
#   'decision_length': '148',
#   'multiple_defendants': 'Y',
#   'damages': defaultdict(float,
#               {'Special': None,
#                'General': None,
#                'Punitive': None,
#                'Aggravated': None,
#                'Future Care': None,
#                'Pecuniary Total': None,
#                'Non-pecuniary': None,
#                'Total': None})}]

# %%
df = rule_based_convert_to_DF(data)

# %%
df.to_csv('second_pass.csv', index=False)

# %%
# IN THE MATTER OF (Re) cases
# client/soliciter

# 

len(t)

# %%
bcj
# Out:
# 45

# %%
t
# Out:
# [<re.Match object; span=(317, 628), match='Between N&C Transportation Ltd., T&S Transportati>,
#  <re.Match object; span=(390, 887), match='Between Christopher Radke, plaintiff, and M.S., a>,
#  <re.Match object; span=(394, 509), match='Between Roger Garside Construction Ltd., Plaintif>,
#  <re.Match object; span=(280, 375), match='Between Texas Rutter, Plaintiff, and George Willi>,
#  <re.Match object; span=(384, 632), match='Between Salico Property Marketing Corporation, Cr>,
#  <re.Match object; span=(294, 375), match='Between David Douglas Schlachter, Plaintiff, and >,
#  <re.Match object; span=(303, 404), match='Between Charles Suzuki, plaintiff, and Jeremy Dun>,
#  <re.Match object; span=(297, 447), match='Between Rebecca Thompson, an infant by her litiga>,
#  <re.Match object; span=(311, 408), match='Between Tammy Thon and Tanya Thon, plaintiffs, an>,
#  <re.Match object; span=(293, 405), match='Between Jaime Jocelyn Patricia Slater, Plaintiff,>,
#  <re.Match object; span=(293, 364), match='Between Andreas Belos, Plaintiff, and Nathan Jame>,
#  <re.Match object; span=(315, 393), match='Between Marie Elizabeth Chevalier, Plaintiff, and>,
#  <re.Match object; span=(311, 409), match='Between Lacey Jean Fontaine, Plaintiff, and Virgi>,
#  <re.Match object; span=(282, 350), match='Between Kyle Ilett, Plaintiff, and Leah Michelle >,
#  <re.Match object; span=(303, 391), match='Between Huda Jokhadar, Plaintiff, and Shahram Deh>,
#  <re.Match object; span=(326, 400), match='Between Julie Vera Lane, Plaintiff, and Megan Ken>,
#  <re.Match object; span=(296, 388), match='Between Karen Loveys, Plaintiff, and Beverly Flee>,
#  <re.Match object; span=(366, 440), match='Between Robert McArthur, Plaintiff, and Danielle >,
#  <re.Match object; span=(294, 369), match='Between Joulnar Salame, Plaintiff, and Brian Doug>,
#  <re.Match object; span=(270, 373), match='Between Harvinder Singh Dhah, Plaintiff, and Dust>,
#  <re.Match object; span=(397, 607), match='Between Ravideep Singh Bassi, Jasmine Kaur Bassi >,
#  <re.Match object; span=(363, 486), match='Between Annette K. Mah, plaintiff (applicant), an>,
#  <re.Match object; span=(324, 396), match='Between David A. Smith, plaintiff, and Kelly Mich>,
#  <re.Match object; span=(308, 381), match='Between Gianluca Tucci, Plaintiff, and Peoples Tr>,
#  <re.Match object; span=(354, 589), match='Between Amy Elizabeth Eissfeldt, an infant, by he>,
#  <re.Match object; span=(363, 519), match='Between Terrance Allen Fleming, Plaintiff, And Ro>,
#  <re.Match object; span=(341, 444), match="Between Miquel Mendoza Cue, Plaintiff, and Roy Br>,
#  <re.Match object; span=(268, 352), match='Between Deidrea Demarzo and Daniel Saliken, Plain>,
#  <re.Match object; span=(371, 514), match='Between Ernie Frers, plaintiff, and Siegfried Ing>,
#  <re.Match object; span=(323, 537), match='Between G.R.A.M. Contracting Ltd., Plaintiff, and>,
#  <re.Match object; span=(436, 944), match="Between The Board of School Trustees of School Di>,
#  None,
#  <re.Match object; span=(355, 480), match='Between Sonia Kaur Johel, Plaintiff, and John Doe>,
#  <re.Match object; span=(369, 435), match='Between J.R.I.G., plaintiff, and James Stewart Ty>,
#  <re.Match object; span=(300, 509), match="Between Kuldip Singh Kandola, Plaintiff, and Mich>,
#  <re.Match object; span=(384, 476), match='Between Ryan Cassidy Langley, Plaintiff, and Nanc>,
#  <re.Match object; span=(382, 468), match='Between Len Kim Mar, Plaintiff, and Robert Gordon>,
#  <re.Match object; span=(268, 334), match='Between Jennilee Mattson, Plaintiff, and Suzanne >,
#  <re.Match object; span=(291, 390), match='Between Michael Gordon Roback, Ph.D., Plaintiff, >,
#  <re.Match object; span=(378, 494), match='Between Scottish & York Insurance Co. Limited, pl>,
#  <re.Match object; span=(288, 354), match='Between Carel Scott, Plaintiff, and Paul Dane Eri>,
#  <re.Match object; span=(285, 348), match='Between Sabita Suedat, Plaintiff, and Karim J. Ka>,
#  <re.Match object; span=(322, 515), match='Between Daniel Wallman, Plaintiff, and John Doe, >,
#  <re.Match object; span=(282, 352), match='Between William Joseph Rycroft, Plaintiff, and Ne>,
#  <re.Match object; span=(368, 495), match='Between The Owners, Strata Plan LMS 1328, plainti>]

# %%
case_type_dict = {'BCJ': 'British Columbia Judgments',
                  'CHFL': 'Canadian Health Facilities Law Guide',
                  'ILR': 'Canadian Insurance Law Reporter Cases',
                  'CCLG': 'Canadian Commercial Law Guide',
                  'OCLG': 'Ontario Corporations Law Guide',
                  'CCSG': 'Canadian Corporate Secretary\'s Guide',
                  'CBPG': 'Canadian Employment Benefits & Pension Guide',
                  'ACLG': 'Alberta Corporations Law Guide',
                  'BREG': 'British Columbia Real Estate Law Guide',
                  'CNLR': 'Canadian Native Law Reporter',
                  'DTC': 'Dominion Tax Cases',
                  'CLLC': 'Canadian Labour Law Reporter',
                  'BCLG': 'British Columbia Corporations Law Guide'}

# %%
for key, count in case_type_counts.items():
    try:
        print(key + ' (' + case_type_dict[key] + '): ' + str(count))
    except:
        print(key + ': ' + str(count))
# Out:
# BCJ (British Columbia Judgments): 3885
# CHFL (Canadian Health Facilities Law Guide): 29
# ILR (Canadian Insurance Law Reporter Cases): 128
# Crown Cases (R. v. ___): 43
# CCLG (Canadian Commercial Law Guide): 5
# OCLG (Ontario Corporations Law Guide): 1
# CCSG (Canadian Corporate Secretary's Guide): 2
# CBPG (Canadian Employment Benefits & Pension Guide): 2
# ACLG (Alberta Corporations Law Guide): 1
# BREG (British Columbia Real Estate Law Guide): 16
# CNLR (Canadian Native Law Reporter): 2
# DTC (Dominion Tax Cases): 2
# CLLC (Canadian Labour Law Reporter): 1
# BCLG (British Columbia Corporations Law Guide): 1

# %%
#4,118
total
# Out:
# 4118
